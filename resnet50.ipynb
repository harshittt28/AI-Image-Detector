# %%
# --------------------------------------
# MOUNT GOOGLE DRIVE
# --------------------------------------
from google.colab import drive
drive.mount('/content/drive')

# --------------------------------------
# IMPORTS
# --------------------------------------
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import os

# --------------------------------------
# DATA PATHS
# --------------------------------------
train_dir = '/content/drive/MyDrive/my_dataset1/my_dataset/train'
test_dir  = '/content/drive/MyDrive/my_dataset1/my_dataset/test'

# --------------------------------------
# DATA GENERATORS
# --------------------------------------
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 16
img_size = (224, 224)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary'
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

# --------------------------------------
# BUILD RESNET50 MODEL
# --------------------------------------
from tensorflow.keras.applications import ResNet50

print("\n============================")
print(" TRAINING : ResNet50 MODEL")
print("============================\n")

base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False   # Freeze everything first

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.4)(x)
x = Dense(64, activation='relu')(x)
preds = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=preds)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# --------------------------------------
# SAVE FOLDER
# --------------------------------------
save_folder = "/content/drive/MyDrive/models/ResNet50"
os.makedirs(save_folder, exist_ok=True)

checkpoint = ModelCheckpoint(
    filepath=f"{save_folder}/best_model.h5",
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# --------------------------------------
# PHASE 1 : TRAIN TOP LAYERS
# --------------------------------------
print("\n============================")
print(" PHASE 1 : Training Only Top Layers")
print("============================\n")

history1 = model.fit(
    train_gen,
    validation_data=test_gen,
    epochs=8,
    callbacks=[checkpoint]
)

# --------------------------------------
# PHASE 2 : FINE-TUNING
# --------------------------------------
print("\n============================")
print(" PHASE 2 : Fine-Tuning ResNet50")
print("============================\n")

base_model.trainable = True

# Unfreeze last 45 layers
for layer in base_model.layers[:-45]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history2 = model.fit(
    train_gen,
    validation_data=test_gen,
    epochs=10,
    callbacks=[checkpoint]
)

# --------------------------------------
# SAVE FINAL MODEL
# --------------------------------------
model.save(f"{save_folder}/final_model.h5")

print("\n====================================")
print(" FINAL MODEL SAVED → final_model.h5")
print(" BEST MODEL SAVED → best_model.h5")
print("====================================\n")

# --------------------------------------
# EVALUATION
# --------------------------------------
print("\n============================")
print(" EVALUATING BEST MODEL")
print("============================\n")

best_model = tf.keras.models.load_model(f"{save_folder}/best_model.h5")
test_loss, test_acc = best_model.evaluate(test_gen)

print(f"\nTest Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")

# --------------------------------------
# TRAINING CURVE PLOTTER
# --------------------------------------
def plot_training_history(history1, history2):
    acc = history1.history['accuracy'] + history2.history['accuracy']
    val_acc = history1.history['val_accuracy'] + history2.history['val_accuracy']
    loss = history1.history['loss'] + history2.history['loss']
    val_loss = history1.history['val_loss'] + history2.history['val_loss']

    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 4))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.axvline(x=8, color='red', linestyle='--', label='Fine-Tuning Start')
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("ResNet50 - Accuracy")
    plt.legend()
    plt.grid(True)

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.axvline(x=8, color='red', linestyle='--', label='Fine-Tuning Start')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("ResNet50 - Loss")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.savefig(f"{save_folder}/training_history.png")
    plt.show()

# Generate plots
plot_training_history(history1, history2)

print("\n===============================")
print(" ResNet50 TRAINING COMPLETE!")
print("===============================\n")
# Out:
# Mounted at /content/drive
# Found 402 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
#
# ============================
#  TRAINING : ResNet50 MODEL
# ============================
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# ============================
#  PHASE 1 : Training Only Top Layers
# ============================
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/8
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5955 - loss: 0.6667
# Epoch 1: val_accuracy improved from -inf to 0.64000, saving model to /content/drive/MyDrive/models/ResNet50/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - accuracy: 0.5968 - loss: 0.6654 - val_accuracy: 0.6400 - val_loss: 0.6438
# Epoch 2/8
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6578 - loss: 0.6147
# Epoch 2: val_accuracy improved from 0.64000 to 0.70000, saving model to /content/drive/MyDrive/models/ResNet50/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.6592 - loss: 0.6132 - val_accuracy: 0.7000 - val_loss: 0.5381
# Epoch 3/8
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7170 - loss: 0.5728
# Epoch 3: val_accuracy improved from 0.70000 to 0.71000, saving model to /content/drive/MyDrive/models/ResNet50/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7181 - loss: 0.5721 - val_accuracy: 0.7100 - val_loss: 0.5204
# Epoch 4/8
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6719 - loss: 0.6013
# Epoch 4: val_accuracy did not improve from 0.71000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.6724 - loss: 0.6013 - val_accuracy: 0.5800 - val_loss: 0.7444
# Epoch 5/8
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6392 - loss: 0.6758
# Epoch 5: val_accuracy improved from 0.71000 to 0.75000, saving model to /content/drive/MyDrive/models/ResNet50/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.6403 - loss: 0.6739 - val_accuracy: 0.7500 - val_loss: 0.5573
# Epoch 6/8
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7553 - loss: 0.4969
# Epoch 6: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.7543 - loss: 0.4983 - val_accuracy: 0.7300 - val_loss: 0.5193
# Epoch 7/8
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7246 - loss: 0.5527
# Epoch 7: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.7248 - loss: 0.5519 - val_accuracy: 0.7500 - val_loss: 0.5205
# Epoch 8/8
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7524 - loss: 0.5236
# Epoch 8: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.7517 - loss: 0.5249 - val_accuracy: 0.7300 - val_loss: 0.5935
#
# ============================
#  PHASE 2 : Fine-Tuning ResNet50
# ============================
#
# Epoch 1/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5680 - loss: 2.8894
# Epoch 1: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 134s 5s/step - accuracy: 0.5711 - loss: 2.8547 - val_accuracy: 0.7500 - val_loss: 0.5825
# Epoch 2/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7112 - loss: 0.8314
# Epoch 2: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - accuracy: 0.7126 - loss: 0.8258 - val_accuracy: 0.6600 - val_loss: 0.6448
# Epoch 3/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7833 - loss: 0.4657
# Epoch 3: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.7835 - loss: 0.4655 - val_accuracy: 0.5600 - val_loss: 0.7067
# Epoch 4/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7912 - loss: 0.4147
# Epoch 4: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 0.7913 - loss: 0.4159 - val_accuracy: 0.5700 - val_loss: 0.7323
# Epoch 5/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8068 - loss: 0.4491
# Epoch 5: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 107s 4s/step - accuracy: 0.8072 - loss: 0.4477 - val_accuracy: 0.6700 - val_loss: 0.6679
# Epoch 6/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8173 - loss: 0.3860
# Epoch 6: val_accuracy did not improve from 0.75000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 110s 4s/step - accuracy: 0.8179 - loss: 0.3851 - val_accuracy: 0.6600 - val_loss: 0.6948
# Epoch 7/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8189 - loss: 0.3527
# Epoch 7: val_accuracy improved from 0.75000 to 0.80000, saving model to /content/drive/MyDrive/models/ResNet50/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 149s 5s/step - accuracy: 0.8190 - loss: 0.3530 - val_accuracy: 0.8000 - val_loss: 0.5491
# Epoch 8/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8522 - loss: 0.3555
# Epoch 8: val_accuracy did not improve from 0.80000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.8526 - loss: 0.3544 - val_accuracy: 0.7600 - val_loss: 0.5389
# Epoch 9/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8973 - loss: 0.2519
# Epoch 9: val_accuracy did not improve from 0.80000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 110s 4s/step - accuracy: 0.8962 - loss: 0.2534 - val_accuracy: 0.7800 - val_loss: 0.5095
# Epoch 10/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8874 - loss: 0.2554
# Epoch 10: val_accuracy improved from 0.80000 to 0.84000, saving model to /content/drive/MyDrive/models/ResNet50/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.8870 - loss: 0.2561 - val_accuracy: 0.8400 - val_loss: 0.4511
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ====================================
#  FINAL MODEL SAVED → final_model.h5
#  BEST MODEL SAVED → best_model.h5
# ====================================
#
#
# ============================
#  EVALUATING BEST MODEL
# ============================
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8368 - loss: 0.3887
#
# Test Accuracy: 0.8400
# Test Loss: 0.4511
# ===============================
#  ResNet50 TRAINING COMPLETE!
# ===============================
